# %% [markdown]
# <img src="Archivos/miia.jpg" width=800x>
#
# # Laboratorio 1
#
# ## Desarrollo de una herramienta analítica usando solo Python
#
# Este laboratorio busca evaluar las habilidades relacionadas con la primera parte del curso, correspondiente a las primeras tres semanas. Este enunciado estará disponible desde la semana 2 y deberá entregarse al final de la semana 4 en el enlace correspondiente. Su desarrollo corresponde al 30% de la calificación total del curso.
#
# Esta actividad responde directamente al segundo objetivo del curso:
# * Implementar una herramienta analítica que permita responder una pregunta de negocio para un problema sencillo de analítica de datos, utilizando únicamente algorítmica básica en Python.
#
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
# 1. Leer datos desde archivos.
# 2. Almacenar datos en  estructuras de Python.
# 3. Crear y llamar funciones correctamente.
# 4. Implementar condicionales diferenciando *if*, *elif* y *else*
# 5. Implementar ciclos diferenciando el propósito de *for* y *while*
# 6. Importar paquetes y utilizar sus funciones.
#
# **NOTAS:**
# - Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito completo de la actividad, y puedas desarrollar tu solución apuntando a él desde el comienzo.

# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Uniandes
# La Universidad de los Andes se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Quiero Estudiar, o Ser Pilo Paga, entre otros, han sido revolucionarios, al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades privadas más importantes del país.
#
# Actualmente, la Universidad quiere evaluar el potencial impacto que tendrían algunos programas de *acción afirmativa* para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas. Se cuenta con información respecto a la edad, género, estado civil, estrato socio-económico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas que han respondido encuestas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.
#
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar la población que sería beneficiaria de las becas. Puntualmente, se espera que, dadas unas reglas de selección (ej.: pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca información sobre la población potencialmente beneficiada, de forma que exista un sustento al momento de definir las reglas de selección.

# %% [markdown]
# ## 1. Obtención e inspección de archivos
#
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo, y por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano. Cada archivo corresponde a una de las variables antes mencionadas y se puede garantizar que todos relacionan a las personas encuestadas en el mismo orden (i.e., la primera línea de todos los archivos corresponde a datos de la primera persona encuestada, la segunda línea a la segunda persona, etc.).
#
# Los archivos con los que se cuenta son:
# * *edades.txt*: un archivo ordenado con las edades de cada persona de la población encuestada
# * *género.txt*: un archivo ordenado con el género de cada persona de la población encuestada
# * *estado_civil.txt*: un archivo ordenado con el estado civil de cada persona de la población encuestada
# * *escolaridad.txt*: un archivo ordenado con el nivel de escolaridad de cada persona de la población encuestada
# * *estrato.txt*: un archivo ordenado con el estrato socio-económico de cada persona de la población encuestada
# * *region.txt*: un archivo ordenado con la región de proveniencia de cada persona de la población encuestada

# %% [markdown]
# **Misión 1**
#
# Poner en variables de Python la información que está en los archivos listados arriba.
#
# * *Versión base*: escribe línea a línea el código necesario para poner en variables de Python la información de cada uno de los archivos.
#
# * *Milla extra*: escribe una función que sea capaz de hacer lo anterior para un archivo y úsala en un ciclo para automatizar la lectura de los diferentes archivos.

# %%
# código
edades = "./Archivos/edad.txt"
genero = "./Archivos/genero.txt"
estado_civil = "./Archivos/estado_civil.txt"
escolaridad = "./Archivos/escolaridad.txt"
estrato = "./Archivos/estrato.txt"
region = "./Archivos/region.txt"
promedio = "./Archivos/promedio.txt"





def read_file(path):
    datos=[]
    with open(path, encoding = "utf-8-sig") as f:
        read=f.readline()
        while read != '':
            datos.append(read.strip())
            read = f.readline()
    return datos


datos_edades = read_file(edades)
datos_genero=read_file(genero)
datos_estado_civil=read_file(estado_civil)
datos_escolaridad=read_file(escolaridad)
datos_estrato=read_file(estrato)
datos_region=read_file(region)
datos_promedio=read_file(promedio)




print("**********datos_edades**********")
print(datos_edades)
print("**********datos_genero**********")
print(datos_genero)
print("**********datos_estado_civil**********")
print(datos_estado_civil)
print("**********datos_escolaridad**********")
print(datos_escolaridad)
print("**********datos_estrato**********")
print(datos_estrato)
print("**********datos_region**********")
print(datos_region)
print("**********datos_promedio**********")
print(datos_promedio)
# Out:
# **********datos_edades**********
# ['36', '66', '24', '55', '26', '69', '79', '54', '51', '80', '30', '64', '40', '53', '47', '24', '76', '65', '38', '37', '71', '51', '51', '33', '24', '71', '78', '75', '38', '49', '49', '53', '62', '26', '67', '68', '70', '57', '47', '30', '44', '22', '30', '64', '21', '54', '35', '52', '27', '20', '59', '40', '23', '58', '71', '77', '70', '31', '19', '31', '75', '63', '79', '67', '46', '79', '30', '19', '64', '52', '79', '35', '74', '18', '22', '58', '77', '22', '73', '59', '18', '46', '35', '38', '80', '65', '41', '46', '36', '46', '56', '37', '67', '20', '46', '62', '70', '31', '20', '64', '78', '66', '45', '43', '70', '43', '24', '58', '62', '60', '80', '73', '73', '57', '42', '51', '52', '58', '39', '43', '66', '32', '49', '44', '57', '39', '21', '27', '31', '28', '44', '80', '71', '33', '22', '78', '60', '70', '62', '45', '78', '78', '42', '21', '44', '38', '19', '31', '58', '69', '34', '69', '80', '20', '59', '29', '33', '29', '44', '55', '47', '26', '47', '20', '43', '27', '29', '21', '70', '69', '45', '69', '34', '28', '50', '79', '29', '53', '36', '39', '57', '62', '42', '51', '57', '67', '52', '58', '36', '27', '70', '21', '55', '50', '46', '75', '54', '80', '61', '78', '21', '76', '61', '67', '66', '27', '74', '21', '21', '55', '45', '21', '22', '30', '64', '78', '52', '61', '19', '53', '43', '66', '34', '43', '70', '27', '53', '40', '32', '33', '63', '69', '22', '58', '23', '44', '65', '20', '39', '54', '24', '54', '50', '59', '20', '19', '19', '36', '48', '59', '25', '74', '36', '57', '66', '60', '56', '48', '68', '60', '50', '30', '36', '78', '75', '36', '80', '48', '74', '47', '40', '71', '57', '46', '77', '29', '77', '65', '35', '29', '
', 'Andina', 'Caribe', 'Orinoquia', 'Pacifica', 'Caribe', 'Amazonia', 'Andina', 'Andina', 'Andina', 'Caribe', 'Andina', 'Orinoquia', 'Pacifica', 'Andina', 'Pacifica', 'Pacifica', 'Caribe', 'Caribe', 'Caribe', 'Pacifica', 'Caribe', 'Caribe', 'Caribe', 'Pacifica', 'Caribe', 'Pacifica', 'Amazonia', 'Andina', 'Orinoquia', 'Andina', 'Andina', 'Orinoquia', 'Pacifica', 'Caribe', 'Pacifica', 'Caribe', 'Andina', 'Pacifica', 'Pacifica', 'Andina', 'Caribe', 'Caribe', 'Pacifica', 'Caribe', 'Caribe', 'Orinoquia', 'Andina', 'Orinoquia', 'Caribe', 'Pacifica', 'Pacifica', 'Caribe', 'Andina', 'Caribe', 'Andina', 'Andina', 'Caribe', 'Pacifica', 'Caribe', 'Caribe', 'Caribe', 'Andina', 'Pacifica', 'Andina', 'Andina', 'Caribe', 'Caribe', 'Orinoquia', 'Pacifica', 'Andina', 'Pacifica', 'Caribe', 'Pacifica', 'Andina', 'Andina', 'Caribe', 'Caribe', 'Caribe', 'Caribe', 'Caribe', 'Pacifica', 'Andina', 'Caribe', 'Andina', 'Andina', 'Pacifica', 'Pacifica', 'Caribe', 'Pacifica', 'Orinoquia', 'Caribe', 'Andina', 'Caribe', 'Pacifica', 'Caribe', 'Pacifica' ...
# **********datos_promedio**********
# ['2.4', '0.9', '3.2', '2.1', '2.1', '2.0', '2.7', '4.9', '2.1', '4.5', '3.0', '3.0', '3.5', '1.8', '1.2', '0.1', '1.0', '3.9', '2.9', '3.0', '3.0', '3.0', '4.3', '2.3', '2.6', '2.3', '3.0', '2.8', '1.0', '2.9', '3.7', '3.2', '3.3', '3.9', '2.6', '2.4', '3.9', '1.8', '3.3', '2.1', '1.9', '1.7', '2.5', '2.9', '1.5', '4.1', '0.9', '3.0', '2.3', '4.5', '2.8', '3.8', '3.3', '3.9', '3.0', '2.7', '2.4', '1.1', '2.6', '3.1', '4.9', '3.1', '3.0', '2.1', '2.2', '2.3', '3.3', '0.8', '1.7', '3.9', '4.3', '2.1', '1.5', '2.1', '4.0', '3.1', '2.9', '0.0', '2.5', '4.0', '2.3', '3.3', '3.5', '1.2', '3.0', '3.4', '2.7', '0.0', '2.1', '2.2', '3.4', '2.6', '3.8', '1.8', '2.0', '2.4', '4.0', '1.9', '1.8', '3.4', '2.6', '3.0', '3.1', '3.1', '3.5', '2.1', '2.2', '3.7', '4.1', '4.7', '3.6', '3.6', '1.4', '3.9', '1.4', '3.8', '1.6', '1.7', '1.8', '3.0', '3.6', '2.1', '2.2', '3.7', '2.7', '2.5', '1.3', '1.2', '2.1', '1.3', '3.2', '1.5', '2.6', '1.2', '4.2', '1.9', '3.6', '4.8', '4.0', '2.8', '3.6', '1.3', '2.2', '1.8', '2.4', '4.0', '3.5', '3.4', '3.0', '3.8', '0.2', '3.4', '3.5', '2.9', '2.0', '1.7', '2.5', '2.3', '1.2', '4.6', '2.3', '4.4', '4.9', '3.7', '0.1', '3.0', '2.0', '1.5', '3.6', '3.8', '2.4', '1.6', '2.8', '3.4', '3.1', '3
# %% [markdown]
# **Misión 2**
#
# Reportar las principales características en los datos.
# * *Versión base*: utilizar métricas básicas como conteos o promedios por categorías en los datos.
# * *Milla extra*: utilizar visualizaciones simples como diagramas de barras, de pastel u otros.

# %%
# código - Funciones

# importación de paquetes necesarios

import matplotlib.pyplot as plt
import math

# función que calcula la media de una lista de datos numéricos
def mean_data (data):
    return sum(data)/len(data)

# función que calcula la mediana de una lista de datos numéricos
def median_data (data):
    half = len(data) // 2
    l.sort()
    if not len(data) % 2:
        return (data[half - 1] + data[half]) / 2.0
    return data[half]


# función que calcula la desviación de una lista de datos numéricos
# Varianza

def var_data (data):
    return sum((i-mean_data)**2 for i in data) / len(data)

#Desviacion estandar

def st_data (data):
    return math.sqrt(var_data)

#Funcion para contar los datos

def contar_data(data):
    return [[x,data.count(x)] for x in set(data)]
    


#Promedio datos edades
int_data_edades= [int(x) for x in datos_edades]
mean_datos_edades=mean_data(int_data_edades)

print("Promedio de edades es: " + str(mean_datos_edades))

#Promedio datos promedio
int_data_promedio= [float(x) for x in datos_promedio]
mean_datos_promedio=mean_data(int_data_promedio)

print("Promedio de puntajes es : " + str(mean_datos_promedio))

#Promedio datos estratos sociales
int_data_estrato= [float(x) for x in datos_estrato]
mean_datos_estrato=mean_data(int_data_estrato)

print("Promedio de estratos de los estudiantes es : " + str(mean_datos_estrato))


#numero de datos genero
int_data_genero= [str(x) for x in datos_genero]
numero_datos=contar_data(datos_genero)

print("Tenemos el siguiente numero de datos para cada genero "+ str(numero_datos))

#numero de datos region

int_data_region= [str(x) for x in datos_region]
numero_region=contar_data(datos_region)

print("Tenemos el siguiente numero de datos para cada region "+ str(numero_region))

#numero de datos estado civil

data_estado_civil= [str(x) for x in datos_estado_civil]
numero_estado_civil=contar_data(data_estado_civil)

print("Tenemos el siguiente numero de estados civiles "+ str(numero_estado_civil))

#numero de datos segun escolaridad

Numero_datos_escolaridad= [str(x) for x in datos_escolaridad]
numero_escolaridad=contar_data(Numero_datos_escolaridad)

print("Tenemos el siguientes datos en escolaridad "+ str(numero_escolaridad))
# Out:
# Promedio de edades es: 48.748
# Promedio de puntajes es : 2.6212000000000004
# Promedio de estratos de los estudiantes es : 2.308
# Tenemos el siguiente numero de datos para cada genero [['masculino', 204], ['femenino', 251], ['otro', 6], ['no binario', 39]]
# Tenemos el siguiente numero de datos para cada region [['Pacifica', 117], ['Caribe', 193], ['Orinoquia', 33], ['Andina', 142], ['Amazonia', 15]]
# Tenemos el siguiente numero de estados civiles [['soltera', 148], ['casada', 199], ['viuda', 16], ['divorciada', 137]]
# Tenemos el siguientes datos en escolaridad [['Maestria', 15], ['Profesional', 117], ['Primaria', 25], ['Secundaria', 343]]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 3, sharey = False,figsize=(16,9))

ax[0,0].boxplot(int_data_edades)
ax[0,0].set_title('Edades', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[0,1].boxplot(int_data_promedio)
ax[0,1].set_title('Promedio de Notas', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[0,2].boxplot(int_data_estrato)
ax[0,2].set_title('Datos Estrato Estudiantes', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[1,0].bar(int_data_genero,mean_datos_estrato)
ax[1,0].set_title('Genero vs Estrato Promedio', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[1,1].bar(int_data_genero,int_data_promedio)
ax[1,1].set_title('Genero vs Promedio', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[1,2].bar(int_data_region,int_data_promedio)
ax[1,2].set_title('Region vs Promedio', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})


plt.show()

# %% [markdown]
# ## 2. Abordaje de la pregunta de negocio
#
# El comité encargado de diseñar el programa de becas ha tenido dificultades para llegar a acuerdos. Algunos piensan que el criterio principal de selección debería ser respecto a lo económico y académico, sin importar otras características personales, mientras que otros piensan que considerar estas características es, de hecho, parte del espíritu del programa.
#
# * El primer grupo sugiere que se deben tomar en orden ascendente los estratos y elegir, en cada uno de ellos, al 2% de personas con promedio académico superior en esa sub-población, hasta que se agoten las becas disponibles. En caso de quedar becas disponibles al final del proceso, se repite el mismo esquema, considerando que ya no se tienen en cuenta las personas que hayan sido elegidas en rondas anteriores.
#
# * El segundo grupo sugiere que los recibidores de becas deben estar igualmente distribuidos entre las diferentes regiones y generos, considerando, por supuesto, que para cada una de esas sub-poblaciones, las personas elegidas sean las de mejores promedios académicos.
#
# Dado que las diferencias entre estos grupos obedecen a su entendimiento particular del problema, el presidente del comité propone utilizar los datos disponibles de las encuestas, sugiriendo que se analice qué características tendría la población de elegidos bajo cada uno de los dos criterios expuestos.

# %% [markdown]
# **Misión 3**
#
# Defina la pregunta de negocio y la pregunta de *analytics* para esta situación.

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

pregunta_negocio = 'Cual criterio se debe usar para la asignacion de becas'

pregunta_analytics = 'Desarrollar una herramienta con modelos descriptivos que apoye el proceso de seleccion de criterios de asignacion de becas'

# %% [markdown]
# **Misión 4**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *primer grupo* mencionado arriba.

# %%
# Codigo

# Datos Consolidados
#Ordena una lista de listas con las siguientes columnas: estrato, promedio, indice, region, estado civil, escolaridad, edad

datos_consolidados=[]

becados_consolidado=[]

for i in range(len(datos_estrato)):
    lista_p=[]   
    lista_p.append(datos_estrato[i])
    lista_p.append(datos_promedio[i])    
    lista_p.append(i)
    lista_p.append(datos_region[i])
    lista_p.append(datos_estado_civil[i])
    lista_p.append(datos_escolaridad[i])
    lista_p.append(datos_edades[i])
    lista_p.append(datos_genero[i])
    datos_consolidados.append(lista_p)

#Variable para determinar el numero de becas a asignar 

No_becas = 50

while No_becas > 0:
    
    print(No_becas)
    
    # Determinar numero de becas por estrato
    datos_estrato_1=[]
    for x in range(len(datos_consolidados)):
        temp=datos_consolidados[x]
        datos_estrato_1.append(temp[0])    

    cont_Estrato=[[x,datos_estrato_1.count(x),math.floor(datos_estrato_1.count(x)*0.02)] for x in set(datos_estrato_1)]


     #Crea un diccionario de estrato y numero de becas asignadas 


    d_becas_e={}
    for j in range(len(cont_Estrato)):
        d_becas_e[cont_Estrato[j][0]]=cont_Estrato[j][2]


    print(d_becas_e)
    No_becas-=sum(d_becas_e.values())


    #Asigna las becas por estrato en orden descendente segun el promedio

    lista_ordenada_e=sorted(datos_consolidados, key=lambda x: (x[0],x[1]),reverse=True)

    for i in range(len(lista_ordenada_e)):
        estudiante_e=lista_ordenada_e[i]
        becas_asignadas_e=d_becas_e[estudiante_e[0]]
        if(becas_asignadas_e>0):            
            estudiante_e.append(1)
            d_becas_e[estudiante_e[0]]-=1
        else:
            estudiante_e.append(0)


    #lista_ordenada_e

    #Filtrar lista para traer solo a los estudiantes sin beca

    becados=[i for i in lista_ordenada_e if i[8] == 1]
    for i in becados:
        becados_consolidado.append(i)
    sin_beca=[i for i in lista_ordenada_e if i[8] == 0]
    for i in sin_beca:
        i.pop(8)
    
    datos_consolidados=sin_beca
    
    print(becados)
    print("Estrato, Promedio,Index,Region,Estado Civil,Escolaridad,Edad, Numero de becas")

for i in becados_consolidado:
    print (i)
# Out:
# 50
# {'2': 3, '1': 2, '5': 0, '4': 0, '3': 3}
# [['3', '4.9', 60, 'Caribe', 'casada', 'Primaria', '75', 'femenino', 1], ['3', '4.9', 471, 'Pacifica', 'soltera', 'Secundaria', '21', 'masculino', 1], ['3', '4.7', 109, 'Pacifica', 'soltera', 'Profesional', '60', 'femenino', 1], ['2', '5.0', 243, 'Caribe', 'divorciada', 'Secundaria', '59', 'femenino', 1], ['2', '4.9', 7, 'Andina', 'casada', 'Secundaria', '54', 'femenino', 1], ['2', '4.9', 207, 'Andina', 'casada', 'Profesional', '21', 'femenino', 1], ['1', '5.0', 376, 'Pacifica', 'soltera', 'Secundaria', '69', 'masculino', 1], ['1', '4.9', 162, 'Andina', 'casada', 'Secundaria', '47', 'masculino', 1]]
# Estrato, Promedio,Index,Region,Estado Civil,Escolaridad,Edad, Numero de becas
# 42
# {'2': 3, '1': 2, '5': 0, '4': 0, '3': 3}
# [['3', '4.6', 159, 'Caribe', 'soltera', 'Profesional', '55', 'masculino', 1], ['3', '4.5', 9, 'Andina', 'soltera', 'Profesional', '80', 'masculino', 1], ['3', '4.5', 49, 'Amazonia', 'soltera', 'Secundaria', '20', 'masculino', 1], ['2', '4.9', 491, 'Caribe', 'casada', 'Profesional', '59', 'masculino', 1], ['2', '4.8', 137, 'Andina', 'divorciada', 'Profesional', '70', 'femenino', 1], ['2', '4.6', 478, 'Amazonia', 'casada', 'Secundaria', '27', 'femenino', 1], ['1', '4.9', 363, 'Pacifica', 'casada', 'Secundaria', '32', 'femenino', 1], ['1', '4.8', 283, 'Andina', 'divorciada', 'Secundaria', '28', 'no binario', 1]]
# Estrato, Promedio,Index,Region,Estado Civil,Escolaridad,Edad, Numero de becas
# 34
# {'2': 3, '1': 2, '5': 0, '4': 0, '3': 3}
# [['3', '4.4', 161, 'Pacifica', 'casada', 'Secundaria', '26', 'masculino', 1], ['3', '4.2', 134, 'Andina', 'soltera', 'Secundaria', '22', 'femenino', 1], ['3', '4.2', 256, 'Caribe', 'casada', 'Secundaria', '56', 'femenino', 1], ['2', '4.5', 409, 'Andina', 'divorciada', 'Secundaria', '58', 'femenino', 1], ['2', '4.5', 452, 'Andina', 'casada', 'Secundaria', '53', 'masculino', 1], ['2', '4.4', 222, 'Andina', 'soltera', 'Profesional', '34', 'masculino', 1], ['1', '4.7', 385, 'Pacifica', 'soltera', 'Secundaria', '49', 'masculino', 1], ['1', '4.3', 287, 'Pacifica', 'soltera', 'Secundaria', '20', 'femenino', 1]]
# Estrato, Promedio,Index,Region,Estado Civil,Escolaridad,Edad, Numero de becas
# 26
# {'2': 3, '1': 2, '5': 0, '4': 0, '3': 2}
# [['3', '4.2', 428, 'Andina', 'casada', 'Profesional', '54', 'masculino', 1], ['3', '4.2', 453, 'Caribe', 'casada', 'Profesional', '36', 'femenino', 1], ['2', '4.4', 308, 'Caribe', 'divorciada', 'Secundaria', '30', 'femenino', 1], ['2', '4.4', 355, 'Pacifica', 'soltera', 'Maestria', '68', 'femenino', 1], ['2', '4.3', 22, 'Caribe', 'casada', 'Secundaria', '51', 'no binario', 1], ['1', '4.3', 398, 'Andina', 'casada', 'Secundaria', '52', 'masculino', 1], ['1', '4.2', 422, 'Orinoquia', 'soltera', 'Secundaria', '50', 'masculino', 1]]
# Estrato, Promedio,Index,Region,Estado Civil,Escolaridad,Edad, Numero de becas
# 19
# {'2': 3, '1': 2, '5': 0, '4': 0, '3': 2}
# [['3', '4.1', 45, 'Andina', 'casada', 'Secundaria', '54', 'femenino', 1], ['3', '4.1', 454, 'Caribe', 'casada', 'Secundaria', '50', 'masculino', 1], ['2', '4.3', 70, 'Caribe', 'casada', 'Secundaria', '79', 'femenino', 1], ['2', '4.2', 262, 'Pacifica', 'casada', 'Secundaria', '36', 'femenino', 1], ['2', '4.0', 96, 'Caribe', 'divorciada', 'Profesional', '70', 'no binario', 1], ['1', '4.1', 108, 'Caribe', 'viuda', 'Profesional', '62', 'femenino', 1], ['1', '4.1', 213, 'Caribe', 'divorciada', 'Secundaria', '30', 'femenino', 1]]
# Estrato, Promedio,Index,Region,Estado Civil,Escolaridad,Edad, Numero de becas
# 12
# {'2': 3, '1': 2, '5': 0, '4': 0, '3': 2}
# [['3', '4.0', 74, 'Andina', 'casada', 'Profesional', '22', 'femenino', 1], ['3', '4.0', 79, 'Pacifica', 'casada', 'Secundaria', '59', 'masculino', 1], ['2', '4.0', 337, 'Pacifica', 'divorciada', 'Profesional', '23', 'femenino', 1], ['2', '3.9', 17, 'Caribe', 'divorciada', 'Secundaria', '65', 'femenino', 1], ['2', '3.9', 33, 'Andina', 'casada', 'Secundaria', '26', 'masculino', 1], ['1', '4.0', 250, 'Pacifica', 'divorciada', 'Secundaria', '25', 'femenino', 1], ['1', '4.0', 253, 'Pacifica', 'soltera', 'Secundaria', '57', 'masculino', 1]]
# Estrato, Promedio,Index,Region,Estado Civil,Escolaridad,Edad, Numero de becas
# 5
# {'2': 3, '1': 1, '5': 0, '4': 0, '3': 2}
# [['3', '4.0', 138, 'Orinoquia', 'divorciada', 'Secundaria', '62', 'masculino', 1], ['3', '4.0', 145, 'Caribe', 'casada', 'Secundaria', '38', 'femenino', 1], ['2', '3.9', 36, 'Caribe', 'divorciada', 'Secundaria', '70', 'femenino', 1], ['2', '3.9', 69, 'Pacifica', 'soltera', 'Secundaria', '52', 'femenino', 1], ['2', '3.9', 113, 'Orinoquia', 'divorciada', 'Profesional', '57', 'femenino', 1], ['1', '4.0', 281, 'Andina', 'casada', 'Secundaria', '53', 'masculino', 1]]
# Estrato, Promedio,Index,Region,Estado Civil,Escolaridad,Edad, Numero de becas
# ['3', '4.9', 60, 'Caribe', 'casada', 'Primaria', '75', 'femenino', 1]
# ['3', '4.9', 471, 'Pacifica', 'soltera', 'Secundaria', '21', 'masculino', 1]
# ['3', '4.7', 109, 'Pacifica', 'soltera', 'Profesional', '60', 'femenino', 1]
# ['2', '5.0', 243, 'Caribe', 'divorciada', 'Secundaria', '59', 'femenino', 1]
# ['2', '4.9', 7, 'Andina', 'casada', 'Secundaria', '54', 'femenino', 1]
# ['2', '4.9', 207, 'Andina', 'casada', 'Profesional', '21', 'femenino', 1]
# ['1', '5.0', 376, 'Pacifica', 'soltera', 'Secundaria', '69', 'masculino', 1]
# ['1', '4.9', 162, 'Andina', 'casada', 'Secundaria', '47', 'masculino', 1]
# ['3', '4.6', 159, 'Caribe', 'soltera', 'Profesional', '55', 'masculino', 1]
# ['3', '4.5', 9, 'Andina', 'soltera', 'Profesional', '80', 'masculino', 1]
# ['3', '4.5', 49, 'Amazonia', 'soltera', 'Secundaria', '20', 'masculino', 1]
# ['2', '4.9', 491, 'Caribe', 'casada', 'Profesional', '59', 'masculino', 1]
# ['2', '4.8', 137, 'Andina', 'divorciada', 'Profesional', '70', 'femenino', 1]
# ['2', '4.6', 478, 'Amazonia', 'casada', 'Secundaria', '27', 'femenino', 1]
# ['1', '4.9', 363, 'Pacifica', 'casada', 'Secundaria', '32', 'femenino', 1]
# ['1', '4.8', 283, 'Andina', 'divorciada', 'Secundaria', '28', 'no binario', 1]
# ['3', '4.4', 161, 'Pacifica', 'casada', 'Secundaria', '26', 'masculino', 1]
# ['3', '4.2', 134, 'Andina', 'soltera', 'Secundaria', '22', 'femenino', 1]
# ['3', '4.2', 256, 'Caribe', 'casada', 'Secundaria', '56', 'femenino', 1]
# ['2', '4.5', 409, 'Andina', 'divorciada', 'Secundaria', '58', 'femenino', 1]
# ['2', '4.5', 452, 'Andina', 'casada', 'Secundaria', '53', 'masculino', 1]
# ['2', '4.4', 222, 'Andina', 'soltera', 'Profesional', '34', 'masculino', 1]
# ['1', '4.7', 385, 'Pacifica', 'soltera', 'Secundaria', '49', 'masculino', 1]
# ['1', '4.3', 287, 'Pacifica', 'soltera', 'Secundaria', '20', 'femenino', 1]
# ['3', '4.2', 428, 'Andina', 'casada', 'Profesional', '54', 'masculino', 1]
# ['3', '4.2', 453, 'Caribe', 'casada', 'Profesional', '36', 'femenino', 1]
# ['2', '4.4', 308, 'Caribe', 'divorciada', 'Secundaria', '30', 'femenino', 1]
# ['2', '4.4', 355, 'Pacifica', 'soltera', 'Maestria', '68', 'femenino', 1]
# ['2', '4.3', 22, 'Caribe', 'casada', 'Secundaria', '51', 'no binario', 1]
# ['1', '4.3', 398, 'Andina', 'casada', 'Secundaria', '52', 'masculino', 1]
# ['1', '4.2', 422, 'Orinoquia', 'soltera', 'Secundaria', '50', 'masculino', 1]
# ['3', '4.1', 45, 'Andina', 'casada', 'Secundaria', '54', 'femenino', 1]
# ['3', '4.1', 454, 'Caribe', 'casada', 'Secundaria', '50', 'masculino', 1]
# ['2', '4.3', 70, 'Caribe', 'casada', 'Secundaria', '79', 'femenino', 1]
# ['2', '4.2', 262, 'Pacifica', 'casada', 'Secundaria', '36', 'femenino', 1]
# ['2', '4.0', 96, 'Caribe', 'divorciada', 'Profesional', '70', 'no binario', 1]
# ['1', '4.1', 108, 'Caribe', 'viuda', 'Profesional', '62', 'femenino', 1]
# ['1', '4.1', 213, 'Caribe', 'divorciada', 'Secundaria', '30', 'femenino', 1]
# ['3', '4.0', 74, 'Andina', 'casada', 'Profesional', '22', 'femenino', 1]
# ['3', '4.0', 79, 'Pacifica', 'casada', 'Secundaria', '59', 'masculino', 1]
# ['2', '4.0', 337, 'Pacifica', 'divorciada', 'Profesional', '23', 'femenino', 1]
# ['2', '3.9', 17, 'Caribe', 'divorciada', 'Secundaria', '65', 'femenino', 1]
# ['2', '3.9', 33, 'Andina', 'casada', 'Secundaria', '26', 'masculino', 1]
# ['1', '4.0', 250, 'Pacifica', 'divorciada', 'Secundaria', '25', 'femenino', 1]
# ['1', '4.0', 253, 'Pacifica', 'soltera', 'Secundaria', '57', 'masculino', 1]
# ['3', '4.0', 138, 'Orinoquia', 'divorciada', 'Secundaria', '62', 'masculino', 1]
# ['3', '4.0', 145, 'Caribe', 'casada', 'Secundaria', '38', 'femenino', 1]
# ['2', '3.9', 36, 'Caribe', 'divorciada', 'Secundaria', '70', 'femenino', 1]
# ['2', '3.9', 69, 'Pacifica', 'soltera', 'Secundaria', '52', 'femenino', 1]
# ['2', '3.9', 113, 'Orinoquia', 'divorciada', 'Profesional', '57', 'femenino', 1]
# ['1', '4.0', 281, 'Andina', 'casada', 'Secundaria', '53', 'masculino', 1]

# %% [markdown]
# **Misión 5**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *segundo grupo* mencionado arriba.

# %%
#Codigo
# crear una lista con la llave Datos Region y Datos Genero

No_becas=50

lista_g=[]
for i in range(len(datos_region)):
    combinacion= datos_region[i]+"-"+ datos_genero[i]
    lista_g.append(combinacion)


cont_region_Genero=[[x,lista_g.count(x),lista_g.count(x)/len(lista_g),math.floor((lista_g.count(x)/len(lista_g))*No_becas)] for x in set(lista_g)]

# Crea un diccionario de region - genero y numero de becas asignadas
d_becas={}
for j in range(len(cont_region_Genero)):
    d_becas[cont_region_Genero[j][0]]=cont_region_Genero[j][3]


#crea una lista ordenada de promedios por region-genero

lista_g2=[]

for i in range(len(datos_region)):
    lista_p2=[]
    combinacion2= datos_region[i]+"-"+ datos_genero[i]
    lista_p2.append(combinacion2)
    lista_p2.append(datos_promedio[i])    
    lista_p2.append(i)
    lista_p2.append(datos_estrato[i])
    lista_p2.append(datos_estado_civil[i])
    lista_p2.append(datos_escolaridad[i])
    lista_p2.append(datos_edades[i])
    lista_p2.append(datos_genero[i])
    lista_p2.append(datos_region[i])
    lista_g2.append(lista_p2)

lista_ordenada=sorted(lista_g2, key=lambda x: (x[0],x[1]),reverse=True)

# Asigna las becas por region-genero en orden descendente segun el promedio

for i in range(len(lista_ordenada)):
    estudiante=lista_ordenada[i]
    becas_asignadas=d_becas[estudiante[0]]
    if(becas_asignadas>0):            
        estudiante.append(1)
        d_becas[estudiante[0]]-=1
    else:
        estudiante.append(0)
        

        
# imprimir la lista de todos los estudiantes y cuales fueron becados

for i in range(len(lista_ordenada)):
    print(lista_ordenada[i])
            
#Filtrar lista para traer solo a los estudiantes becados

Lista_Becados = [i for i in lista_ordenada if i[9] == 1]

print("******************Lista solo becados***************")
print("Region_Genero, Promedio,Index,Estrato,Estado Civil,Escolaridad,Edad,Genero, Numero de becas")

for i in range(len(Lista_Becados)):
    print(Lista_Becados[i])
# Out:
# ['Pacifica-no binario', '4.0', 361, '1', 'divorciada', 'Profesional', '73', 'no binario', 'Pacifica', 1]
# ['Pacifica-no binario', '3.6', 179, '3', 'soltera', 'Secundaria', '39', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '3.3', 66, '2', 'divorciada', 'Secundaria', '30', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '3.3', 81, '2', 'soltera', 'Secundaria', '46', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '3.3', 347, '1', 'divorciada', 'Profesional', '59', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '2.2', 313, '1', 'soltera', 'Profesional', '25', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '2.0', 166, '1', 'casada', 'Secundaria', '29', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '1.5', 178, '2', 'divorciada', 'Secundaria', '36', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '1.3', 231, '3', 'divorciada', 'Secundaria', '69', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '1.2', 14, '1', 'divorciada', 'Secundaria', '47', 'no binario', 'Pacifica', 0]
# ['Pacifica-no binario', '0.2', 317, '1', 'soltera', 'Secundaria', '64', 'no binario', 'Pacifica', 0]
# ['Pacifica-masculino', '5.0', 376, '1', 'soltera', 'Secundaria', '69', 'masculino', 'Pacifica', 1]
# ['Pacifica-masculino', '4.9', 471, '3', 'soltera', 'Secundaria', '21', 'masculino', 'Pacifica', 1]
# ['Pacifica-masculino', '4.7', 385, '1', 'soltera', 'Secundaria', '49', 'masculino', 'Pacifica', 1]
# ['Pacifica-masculino', '4.4', 161, '3', 'casada', 'Secundaria', '26', 'masculino', 'Pacifica', 1]
# ['Pacifica-masculino', '4.0', 79, '3', 'casada', 'Secundaria', '59', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '4.0', 253, '1', 'soltera', 'Secundaria', '57', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '4.0', 289, '1', 'casada', 'Secundaria', '54', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.9', 188, '3', 'casada', 'Primaria', '36', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.8', 240, '2', 'casada', 'Secundaria', '24', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.7', 472, '3', 'divorciada', 'Profesional', '54', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.5', 248, '1', 'divorciada', 'Secundaria', '48', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.4', 151, '2', 'casada', 'Secundaria', '69', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.4', 384, '4', 'casada', 'Secundaria', '71', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.3', 52, '3', 'soltera', 'Profesional', '23', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.3', 270, '2', 'divorciada', 'Secundaria', '40', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.2', 403, '2', 'casada', 'Profesional', '79', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.1', 103, '3', 'casada', 'Maestria', '43', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.0', 54, '2', 'viuda', 'Secundaria', '71', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.0', 101, '2', 'casada', 'Secundaria', '66', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '3.0', 176, '2', 'casada', 'Secundaria', '29', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.9', 43, '2', 'soltera', 'Secundaria', '64', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.9', 76, '3', 'soltera', 'Secundaria', '77', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.7', 55, '3', 'divorciada', 'Secundaria', '77', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.6', 371, '4', 'casada', 'Profesional', '77', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.5', 312, '3', 'soltera', 'Profesional', '76', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.5', 440, '2', 'soltera', 'Secundaria', '20', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.4', 35, '2', 'divorciada', 'Profesional', '68', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.4', 391, '3', 'casada', 'Primaria', '60', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.2', 106, '1', 'casada', 'Primaria', '24', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.1', 3, '3', 'casada', 'Secundaria', '55', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '2.1', 418, '3', 'casada', 'Primaria', '66', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '1.9', 40, '2', 'divorciada', 'Secundaria', '44', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '1.9', 463, '2', 'casada', 'Secundaria', '54', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '1.8', 402, '3', 'casada', 'Secundaria', '78', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '1.7', 41, '2', 'soltera', 'Secundaria', '22', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '1.2', 158, '2', 'casada', 'Profesional', '44', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '1.1', 184, '1', 'casada', 'Secundaria', '57', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '1.1', 290, '1', 'casada', 'Profesional', '54', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '1.1', 332, '3', 'casada', 'Secundaria', '70', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '0.8', 67, '3', 'divorciada', 'Secundaria', '19', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '0.6', 425, '2', 'casada', 'Secundaria', '18', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '0.5', 246, '2', 'casada', 'Secundaria', '19', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '0.4', 251, '4', 'soltera', 'Secundaria', '74', 'masculino', 'Pacifica', 0]
# ['Pacifica-masculino', '0.1', 457, '1', 'soltera', 'Profesional', '74', 'masculino', 'Pacifica', 0]
# ['Pacifica-femenino', '4.9', 363, '1', 'casada', 'Secundaria', '32', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.7', 109, '3', 'soltera', 'Profesional', '60', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.4', 355, '2', 'soltera', 'Maestria', '68', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.3', 287, '1', 'soltera', 'Secundaria', '20', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.2', 262, '2', 'casada', 'Secundaria', '36', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.0', 250, '1', 'divorciada', 'Secundaria', '25', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.0', 337, '2', 'divorciada', 'Profesional', '23', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.9', 69, '2', 'soltera', 'Secundaria', '52', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.7', 107, '1', 'divorciada', 'Secundaria', '58', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.7', 294, '3', 'divorciada', 'Primaria', '39', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.6', 368, '1', 'soltera', 'Profesional', '44', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.6', 386, '2', 'divorciada', 'Secundaria', '28', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.5', 252, '2', 'divorciada', 'Profesional', '36', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.5', 300, '3', 'casada', 'Secundaria', '79', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.5', 397, '3', 'soltera', 'Secundaria', '57', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.4', 173, '3', 'divorciada', 'Maestria', '28', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.4', 370, '2', 'divorciada', 'Profesional', '46', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.3', 234, '1', 'soltera', 'Secundaria', '23', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.2', 2, '3', 'divorciada', 'Secundaria', '24', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.1', 426, '2', 'divorciada', 'Profesional', '44', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.0', 11, '2', 'casada', 'Primaria', '64', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3.0', 20, '3', 'soltera', 'Secundaria', '71', 'femenino', 'Pacifica', 0]
# ['Pacifica-femenino', '3
 'masculino', 'Orinoquia', 0]
# ['Orinoquia-masculino', '2.0', 277, '4', 'viuda', 'Secundaria', '65', 'masculino', 'Orinoquia', 0]
# ['Orinoquia-masculino', '2.0', 410, '2', 'casada', 'Secundaria', '22', 'masculino', 'Orinoquia', 0]
# ['Orinoquia-masculino', '1.8', 98, '2', 'casada', 'Profesional', '20', 'masculino', 'Orinoquia', 0]
# ['Orinoquia-masculino', '1.3', 126, '3', 'divorciada', 'Secundaria', '21', 'masculino', 'Orinoquia', 0]
# ['Orinoquia-masculino', '1.3', 129, '4', 'divorciada', 'Secundaria', '28', 'masculino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '3.9', 113, '2', 'divorciada', 'Profesional', '57', 'femenino', 'Orinoquia', 1]
# ['Orinoquia-femenino', '3.4', 99, '5', 'viuda', 'Secundaria', '64', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '3.0', 228, '3', 'casada', 'Secundaria', '32', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '2.9', 153, '4', 'casada', 'Secundaria', '20', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '2.8', 50, '3', 'soltera', 'Secundaria', '59', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '2.8', 189, '2', 'soltera', 'Secundaria', '27', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '2.7', 286, '1', 'soltera', 'Primaria', '57', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '2.7', 303, '2', 'soltera', 'Secundaria', '45', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '2.5', 261, '2', 'divorciada', 'Secundaria', '30', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '2.3', 65, '2', 'casada', 'Secundaria', '79', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '2.1', 73, '2', 'casada', 'Secundaria', '18', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '1.9', 342, '2', 'casada', 'Profesional', '49', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '1.7', 117, '3', 'divorciada', 'Secundaria', '58', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '1.5', 44, '2', 'soltera', 'Secundaria', '21', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '1.3', 322, '2', 'divorciada', 'Profesional', '48', 'femenino', 'Orinoquia', 0]
# ['Orinoquia-femenino', '1.0', 306, '3', 'casada', 'Primaria', '24', 'femenino', 'Orinoquia', 0]
# ['Caribe-otro', '3.6', 136, '2', 'soltera', 'Secundaria', '60', 'otro', 'Caribe', 0]
# ['Caribe-otro', '0.1', 164, '2', 'soltera', 'Secundaria', '43', 'otro', 'Caribe', 0]
# ['Caribe-no binario', '4.3', 22, '2', 'casada', 'Secundaria', '51', 'no binario', 'Caribe', 1]
# ['Caribe-no binario', '4.0', 96, '2', 'divorciada', 'Profesional', '70', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '3.5', 104, '1', 'soltera', 'Profesional', '70', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '3.5', 467, '3', 'soltera', 'Secundaria', '67', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '3.2', 31, '2', 'divorciada', 'Secundaria', '53', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '3.0', 369, '2', 'divorciada', 'Secundaria', '54', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '2.9', 413, '2', 'soltera', 'Secundaria', '38', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '2.5', 78, '2', 'casada', 'Secundaria', '73', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '2.2', 89, '1', 'divorciada', 'Secundaria', '46', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '2.1', 88, '3', 'casada', 'Secundaria', '36', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '2.1', 438, '2', 'casada', 'Profesional', '53', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '2.0', 5, '3', 'divorciada', 'Secundaria', '69', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '0.5', 423, '3', 'casada', 'Secundaria', '24', 'no binario', 'Caribe', 0]
# ['Caribe-no binario', '0.0', 77, '1', 'divorciada', 'Profesional', '22', 'no binario', 'Caribe', 0]
# ['Caribe-masculino', '4.9', 491, '2', 'casada', 'Profesional', '59', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '4.6', 159, '3', 'soltera', 'Profesional', '55', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '4.1', 454, '3', 'casada', 'Secundaria', '50', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '4.0', 319, '3', 'soltera', 'Profesional', '74', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '4.0', 434, '1', 'soltera', 'Secundaria', '53', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '3.8', 169, '2', 'divorciada', 'Secundaria', '69', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '3.7', 202, '3', 'divorciada', 'Secundaria', '61', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '3.7', 291, '3', 'casada', 'Profesional', '18', 'masculino', 'Caribe', 0]
# ['Caribe-masculino', '3.7', 489, '1', 'casada', 'Secundaria', '76', 'masculino', 'Caribe', 0]
# ['Caribe-masculino', '3
 'masculino', 'Caribe', 0]
# ['Caribe-masculino', '0.3', 436, '3', 'casada', 'Secundaria', '19', 'masculino', 'Caribe', 0]
# ['Caribe-masculino', '0.2', 211, '2', 'casada', 'Profesional', '21', 'masculino', 'Caribe', 0]
# ['Caribe-masculino', '0.0', 87, '4', 'casada', 'Profesional', '46', 'masculino', 'Caribe', 0]
# ['Caribe-femenino', '5.0', 243, '2', 'divorciada', 'Secundaria', '59', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.9', 60, '3', 'casada', 'Primaria', '75', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.4', 308, '2', 'divorciada', 'Secundaria', '30', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.3', 70, '2', 'casada', 'Secundaria', '79', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.2', 256, '3', 'casada', 'Secundaria', '56', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.2', 453, '3', 'casada', 'Profesional', '36', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.1', 108, '1', 'viuda', 'Profesional', '62', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.1', 213, '1', 'divorciada', 'Secundaria', '30', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.0', 145, '3', 'casada', 'Secundaria', '38', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.0', 433, '3', 'casada', 'Secundaria', '63', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '3.9', 17, '2', 'divorciada', 'Secundaria', '65', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.9', 36, '2', 'divorciada', 'Secundaria', '70', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.9', 53, '4', 'casada', 'Secundaria', '58', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.9', 193, '1', 'casada', 'Secundaria', '50', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.9', 377, '1', 'casada', 'Secundaria', '69', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.8', 51, '2', 'casada', 'Profesional', '40', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.7', 30, '1', 'casada', 'Secundaria', '49', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.7', 123, '2', 'divorciada', 'Profesional', '44', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.7', 367, '2', 'divorciada', 'Profesional', '47', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.7', 466, '1', 'soltera', 'Secundaria', '24', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.6', 120, '3', 'casada', 'Profesional', '66', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.6', 168, '4', 'soltera', 'Secundaria', '70', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.6', 331, '1', 'divorciada', 'Secundaria', '48', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.6', 442, '3', 'casada', 'Maestria', '25', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.5', 12, '2', 'casada', 'Secundaria', '40', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.5', 82, '2', 'divorciada', 'Secundaria', '35', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.5', 323, '3', 'casada', 'Profesional', '65', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.5', 352, '2', 'casada', 'Primaria', '48', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.5', 455, '1', 'soltera', 'Secundaria', '76', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.4', 450, '3', 'divorciada', 'Profesional', '33', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.4', 460, '1', 'soltera', 'Secundaria', '41', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.4', 470, '3', 'divorciada', 'Secundaria', '35', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.3', 38, '5', 'casada', 'Secundaria', '47', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.3', 242, '5', 'casada', 'Profesional', '50', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.3', 462, '1', 'viuda', 'Maestria', '75', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.2', 326, '3', 'casada', 'Profesional', '31', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.2', 335, '3', 'casada', 'Maestria', '45', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.2', 479, '3', 'casada', 'Secundaria', '73', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.1', 187, '2', 'divorciada', 'Secundaria', '58', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.1', 316, '3', 'casada', 'Profesional', '53', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.1', 318, '1', 'soltera', 'Profesional', '32', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.0', 10, '2', 'soltera', 'Secundaria', '30', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.0', 47, '2', 'divorciada', 'Secundaria', '52', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.0', 84, '2', 'divorciada', 'Secundaria', '80', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.0', 181, '4', 'soltera', 'Secundaria', '62', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '3.0', 340, '2', 'soltera', 'Secundaria', '34', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.9', 177, '2', 'soltera', 'Profesional', '53', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.9', 218, '2', 'casada', 'Secundaria', '19', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.9', 353, '2', 'casada', 'Secundaria', '41', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.8', 27, '3', 'soltera', 'Secundaria', '75', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.8', 139, '2', 'casada', 'Secundaria', '45', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.8', 333, '1', 'divorciada', 'Primaria', '57', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.7', 124, '3', 'soltera', 'Secundaria', '57', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.7', 310, '3', 'casada', 'Secundaria', '52', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.7', 469, '3', 'viuda', 'Secundaria', '50', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.5', 125, '3', 'divorciada', 'Secundaria', '39', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.5', 156, '2', 'soltera', 'Secundaria', '33', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.5', 204, '3', 'casada', 'Profesional', '66', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.5', 235, '3', 'viuda', 'Profesional', '44', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.5', 350, '4', 'divorciada', 'Secundaria', '42', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.4', 56, '1', 'viuda', 'Profesional', '70', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.4', 223, '2', 'soltera', 'Secundaria', '43', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.4', 229, '2', 'soltera', 'Secundaria', '33', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.4', 239, '1', 'casada', 'Secundaria', '54', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.4', 296, '5', 'casada', 'Secundaria', '56', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.3', 48, '2', 'casada', 'Secundaria', '27', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.3', 80, '4', 'divorciada', 'Profesional', '18', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.3', 157, '1', 'casada', 'Secundaria', '29', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.3', 292, '3', 'divorciada', 'Secundaria', '75', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.3', 468, '1', 'casada', 'Secundaria', '32', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.2', 142, '4', 'divorciada', 'Secundaria', '42', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.2', 197, '1', 'soltera', 'Secundaria', '80', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.2', 297, '3', 'soltera', 'Profesional', '71', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.1', 8, '2', 'soltera', 'Secundaria', '51', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.1', 105, '2', 'casada', 'Secundaria', '43', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.1', 128, '1', 'soltera', 'Secundaria', '31', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.1', 226, '3', 'divorciada', 'Profesional', '53', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.1', 293, '3', 'divorciada', 'Secundaria', '45', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.1', 495, '5', 'casada', 'Secundaria', '23', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.0', 245, '2', 'soltera', 'Secundaria', '19', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.0', 439, '3', 'casada', 'Profesional', '65', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '2.0', 461, '5', 'casada', 'Profesional', '20', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.9', 135, '3', 'divorciada', 'Secundaria', '78', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.9', 328, '2', 'casada', 'Profesional', '35', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.8', 37, '2', 'divorciada', 'Primaria', '57', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.8', 118, '2', 'casada', 'Maestria', '39', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.8', 143, '3', 'soltera', 'Profesional', '21', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.7', 155, '3', 'soltera', 'Secundaria', '29', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.6', 171, '2', 'soltera', 'Secundaria', '69', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.6', 237, '2', 'divorciada', 'Secundaria', '20', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.5', 414, '3', 'casada', 'Primaria', '31', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.4', 114, '4', 'casada', 'Profesional', '42', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.4', 232, '1', 'divorciada', 'Profesional', '22', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.4', 255, '2', 'divorciada', 'Secundaria', '60', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.4', 284, '3', 'divorciada', 'Secundaria', '61', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.3', 141, '2', 'soltera', 'Profesional', '78', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.3', 208, '2', 'casada', 'Profesional', '21', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.3', 448, '3', 'casada', 'Profesional', '43', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.2', 127, '3', 'casada', 'Profesional', '27', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.2', 415, '2', 'soltera', 'Secundaria', '39', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.1', 57, '2', 'casada', 'Secundaria', '31', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.0', 28, '3', 'soltera', 'Secundaria', '38', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.0', 225, '2', 'divorciada', 'Profesional', '27', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '1.0', 399, '3', 'divorciada', 'Secundaria', '22', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '0.9', 346, '2', 'soltera', 'Secundaria', '70', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '0.1', 485, '2', 'soltera', 'Secundaria', '19', 'femenino', 'Caribe', 0]
# ['Caribe-femenino', '0.0', 383, '3', 'divorciada', 'Secundaria', '67', 'femenino', 'Caribe', 0]
# ['Andina-otro', '2.4', 373, '3', 'soltera', 'Secundaria', '34', 'otro', 'Andina', 0]
# ['Andina-no binario', '4.8', 259, '5', 'soltera', 'Secundaria', '60', 'no binario', 'Andina', 1]
# ['Andina-no binario', '4.8', 283, '1', 'divorciada', 'Secundaria', '28', 'no binario', 'Andina', 0]
# ['Andina-no binario', '3.7', 400, '3', 'soltera', 'Profesional', '76', 'no binario', 'Andina', 0]
# ['Andina-no binario', '3.5', 302, '3', 'viuda', 'Secundaria', '75', 'no binario', 'Andina', 0]
# ['Andina-no binario', '3.1', 427, '1', 'casada', 'Primaria', '80', 'no binario', 'Andina', 0]
# ['Andina-no binario', '2.7', 285, '4', 'casada', 'Secundaria', '40', 'no binario', 'Andina', 0]
# ['Andina-no binario', '2.6', 34, '2', 'casada', 'Secundaria', '67', 'no binario', 'Andina', 0]
# ['Andina-no binario', '2.1', 227, '3', 'casada', 'Secundaria', '40', 'no binario', 'Andina', 0]
# ['Andina-no binario', '2.1', 497, '1', 'casada', 'Profesional', '50', 'no binario', 'Andina', 0]
# ['Andina-no binario', '0.9', 46, '2', 'casada', 'Secundaria', '35', 'no binario', 'Andina', 0]
# ['Andina-no binario', '0.8', 260, '2', 'soltera', 'Secundaria', '50', 'no binario', 'Andina', 0]
# ['Andina-no binario', '0.2', 459, '2', 'divorciada', 'Profesional', '22', 'no binario', 'Andina', 0]
# ['Andina-masculino', '4.9', 162, '1', 'casada', 'Secundaria', '47', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.8', 394, '4', 'divorciada', 'Profesional', '69', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.5', 9, '3', 'soltera', 'Profesional', '80', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.5', 452, '2', 'casada', 'Secundaria', '53', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.4', 222, '2', 'soltera', 'Profesional', '34', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.3', 398, '1', 'casada', 'Secundaria', '52', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.2', 428, '3', 'casada', 'Profesional', '54', 'masculino', 'Andina', 0]
# ['Andina-masculino', '4.0', 281, '1', 'casada', 'Secundaria', '53', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.9', 33, '2', 'casada', 'Secundaria', '26', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.9', 374, '3', 'soltera', 'Profesional', '74', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.8', 149, '3', 'casada', 'Profesional', '69', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.8', 175, '1', 'casada', 'Secundaria', '79', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.8', 458, '2', 'casada', 'Secundaria', '64', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.7', 163, '1', 'viuda', 'Profesional', '20', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.7', 305, '1', 'soltera', 'Secundaria', '55', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.7', 330, '2', 'casada', 'Primaria', '71', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.6', 111, '1', 'divorciada', 'Secundaria', '73', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.6', 140, '1', 'soltera', 'Secundaria', '78', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.6', 311, '3', 'soltera', 'Profesional', '29', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.6', 338, '2', 'soltera', 'Secundaria', '26', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.5', 336, '2', 'casada', 'Secundaria', '68', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.4', 201, '1', 'casada', 'Profesional', '76', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.4', 247, '3', 'soltera', 'Secundaria', '36', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.4', 492, '2', 'casada', 'Profesional', '49', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.3', 185, '3', 'casada', 'Secundaria', '67', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.2', 130, '3', 'casada', 'Profesional', '44', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.2', 233, '3', 'soltera', 'Secundaria', '58', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.2', 266, '3', 'soltera', 'Secundaria', '80', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.2', 358, '3', 'casada', 'Secundaria', '24', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.2', 416, '3', 'casada', 'Secundaria', '55', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.1', 61, '1', 'soltera', 'Profesional', '63', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.1', 392, '4', 'divorciada', 'Primaria', '44', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.0', 19, '2', 'casada', 'Profesional', '37', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.0', 212, '2', 'casada', 'Maestria', '22', 'masculino', 'Andina', 0]
# ['Andina-masculino', '3.0', 329, '2', 'soltera', 'Secundaria', '48', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.9', 18, '3', 'soltera', 'Secundaria', '38', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.9', 421, '1', 'divorciada', 'Secundaria', '28', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.8', 203, '2', 'casada', 'Secundaria', '67', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.7', 349, '2', 'soltera', 'Secundaria', '20', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.7', 395, '2', 'casada', 'Secundaria', '75', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.6', 327, '3', 'soltera', 'Secundaria', '63', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.4', 0, '5', 'casada', 'Secundaria', '36', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.4', 170, '2', 'soltera', 'Secundaria', '45', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.4', 186, '2', 'divorciada', 'Secundaria', '52', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.3', 339, '3', 'soltera', 'Secundaria', '37', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.2', 388, '2', 'soltera', 'Secundaria', '58', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.2', 480, '1', 'viuda', 'Secundaria', '26', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.2', 483, '3', 'divorciada', 'Secundaria', '70', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.1', 63, '1', 'divorciada', 'Profesional', '67', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.1', 244, '1', 'divorciada', 'Secundaria', '20', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.0', 258, '3', 'casada', 'Secundaria', '68', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.0', 344, '2', 'soltera', 'Secundaria', '42', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.0', 387, '1', 'casada', 'Secundaria', '56', 'masculino', 'Andina', 0]
# ['Andina-masculino', '2.0', 490, '3', 'casada', 'Secundaria', '34', 'masculino', 'Andina', 0]
# ['Andina-masculino', '1.9', 420, '3', 'casada', 'Secundaria', '57', 'masculino', 'Andina', 0]
# ['Andina-masculino', '1.7', 389, '4', 'casada', 'Profesional', '68', 'masculino', 'Andina', 0]
# ['Andina-masculino', '1.3', 465, '2', 'casada', 'Secundaria', '38', 'masculino', 'Andina', 0]
# ['Andina-masculino', '1.1', 441, '1', 'divorciada', 'Secundaria', '45', 'masculino', 'Andina', 0]
# ['Andina-masculino', '1.0', 275, '3', 'divorciada', 'Secundaria', '29', 'masculino', 'Andina', 0]
# ['Andina-masculino', '1.0', 412, '1', 'soltera', 'Secundaria', '74', 'masculino', 'Andina', 0]
# ['Andina-masculino', '1.0', 431, '5', 'casada', 'Secundaria', '79', 'masculino', 'Andina', 0]
# ['Andina-masculino', '0.9', 1, '1', 'divorciada', 'Profesional', '66', 'masculino', 'Andina', 0]
# ['Andina-masculino', '0.9', 264, '2', 'divorciada', 'Secundaria', '75', 'masculino', 'Andina', 0]
# ['Andina-masculino', '0.8', 493, '1', 'divorciada', 'Secundaria', '23', 'masculino', 'Andina', 0]
# ['Andina-masculino', '0.6', 476, '2', 'casada', 'Secundaria', '38', 'masculino', 'Andina', 0]
# ['Andina-masculino', '0.4', 381, '1', 'soltera', 'Secundaria', '24', 'masculino', 'Andina', 0]
# ['Andina-masculino', '0.3', 249, '3', 'casada', 'Primaria', '59', 'masculino', 'Andina', 0]
# ['Andina-masculino', '0.2', 424, '2', 'divorciada', 'Secundaria', '76', 'masculino', 'Andina', 0]
# ['Andina-femenino', '4.9', 7, '2', 'casada', 'Secundaria', '54', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.9', 207, '2', 'casada', 'Profesional', '21', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.8', 137, '2', 'divorciada', 'Profesional', '70', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.5', 409, '2', 'divorciada', 'Secundaria', '58', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.2', 134, '3', 'soltera', 'Secundaria', '22', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.1', 45, '3', 'casada', 'Secundaria', '54', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.0', 74, '3', 'casada', 'Profesional', '22', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.9', 356, '2', 'divorciada', 'Secundaria', '79', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.8', 92, '1', 'soltera', 'Secundaria', '67', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.8', 115, '2', 'divorciada', 'Profesional', '51', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.8', 321, '1', 'viuda', 'Maestria', '52', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.8', 366, '2', 'divorciada', 'Profesional', '74', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.7', 378, '4', 'divorciada', 'Secundaria', '62', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.6', 110, '2', 'soltera', 'Primaria', '80', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.6', 210, '3', 'casada', 'Profesional', '45', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.6', 314, '2', 'soltera', 'Secundaria', '58', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.5', 146, '2', 'divorciada', 'Profesional', '19', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.5', 152, '3', 'divorciada', 'Primaria', '80', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.5', 447, '2', 'casada', 'Secundaria', '33', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.4', 147, '3', 'divorciada', 'Secundaria', '31', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.3', 224, '3', 'soltera', 'Secundaria', '70', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.2', 451, '1', 'soltera', 'Secundaria', '46', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.1', 75, '1', 'divorciada', 'Profesional', '58', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.1', 390, '2', 'divorciada', 'Secundaria', '42', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.1', 444, '1', 'soltera', 'Profesional', '66', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.1', 486, '2', 'soltera', 'Secundaria', '80', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.0', 26, '3', 'soltera', 'Secundaria', '78', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.0', 62, '2', 'soltera', 'Secundaria', '79', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.0', 148, '2', 'casada', 'Secundaria', '58', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.0', 182, '2', 'casada', 'Profesional', '42', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.0', 230, '1', 'soltera', 'Profesional', '63', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.0', 273, '3', 'soltera', 'Secundaria', '46', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.0', 304, '2', 'divorciada', 'Secundaria', '38', 'femenino', 'Andina', 0]
# ['Andina-femenino', '3.0', 407, '2', 'soltera', 'Secundaria', '66', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.9', 29, '1', 'divorciada', 'Secundaria', '49', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.9', 496, '1', 'viuda', 'Secundaria', '24', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.7', 498, '2', 'divorciada', 'Secundaria', '54', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.6', 24, '3', 'casada', 'Profesional', '24', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.6', 91, '2', 'casada', 'Secundaria', '37', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.6', 100, '1', 'soltera', 'Secundaria', '78', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.6', 236, '3', 'soltera', 'Secundaria', '65', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.5', 209, '1', 'casada', 'Secundaria', '55', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.4', 144, '3', 'soltera', 'Primaria', '44', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.3', 206, '4', 'casada', 'Profesional', '74', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.3', 271, '4', 'soltera', 'Secundaria', '71', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.2', 404, '4', 'casada', 'Secundaria', '28', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.1', 348, '3', 'soltera', 'Secundaria', '29', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.0', 94, '3', 'casada', 'Secundaria', '46', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.0', 154, '2', 'divorciada', 'Primaria', '59', 'femenino', 'Andina', 0]
# ['Andina-femenino', '2.0', 359, '1', 'casada', 'Secundaria', '24', 'femenino', 'Andina', 0]
# ['Andina-femenino', '1.9', 268, '3', 'soltera', 'Secundaria', '74', 'femenino', 'Andina', 0]
# ['Andina-femenino', '1.9', 282, '4', 'soltera', 'Secundaria', '22', 'femenino', 'Andina', 0]
# ['Andina-femenino', '1.8', 93, '1', 'casada', 'Profesional', '20', 'femenino', 'Andina', 0]
# ['Andina-femenino', '1.7', 445, '2', 'casada', 'Maestria', '25', 'femenino', 'Andina', 0]
# ['Andina-femenino', '1.6', 116, '2', 'casada', 'Secundaria', '52', 'femenino', 'Andina', 0]
# ['Andina-femenino', '1.4', 112, '3', 'divorciada', 'Secundaria', '73', 'femenino', 'Andina', 0]
# ['Andina-femenino', '1.3', 183, '3', 'casada', 'Secundaria', '51', 'femenino', 'Andina', 0]
# ['Andina-femenino', '0.6', 288, '1', 'soltera', 'Secundaria', '43', 'femenino', 'Andina', 0]
# ['Andina-femenino', '0.2', 150, '2', 'soltera', 'Profesional', '34', 'femenino', 'Andina', 0]
# ['Andina-femenino', '0.1', 405, '2', 'casada', 'Profesional', '50', 'femenino', 'Andina', 0]
# ['Andina-femenino', '0.0', 393, '4', 'casada', 'Secundaria', '37', 'femenino', 'Andina', 0]
# ['Amazonia-otro', '3.1', 195, '4', 'casada', 'Secundaria', '75', 'otro', 'Amazonia', 0]
# ['Amazonia-otro', '3.0', 456, '2', 'divorciada', 'Secundaria', '80', 'otro', 'Amazonia', 0]
# ['Amazonia-no binario', '1.5', 375, '3', 'casada', 'Secundaria', '21', 'no binario', 'Amazonia', 0]
# ['Amazonia-no binario', '0.5', 241, '3', 'divorciada', 'Secundaria', '54', 'no binario', 'Amazonia', 0]
# ['Amazonia-masculino', '4.5', 49, '3', 'soltera', 'Secundaria', '20', 'masculino', 'Amazonia', 0]
# ['Amazonia-masculino', '3.3', 488, '3', 'soltera', 'Secundaria', '39', 'masculino', 'Amazonia', 0]
# ['Amazonia-masculino', '3.1', 102, '1', 'casada', 'Profesional', '45', 'masculino', 'Amazonia', 0]
# ['Amazonia-masculino', '2.7', 6, '4', 'casada', 'Secundaria', '79', 'masculino', 'Amazonia', 0]
# ['Amazonia-masculino', '1.2', 83, '1', 'divorciada', 'Maestria', '38', 'masculino', 'Amazonia', 0]
# ['Amazonia-masculino', '0.9', 301, '4', 'casada', 'Secundaria', '30', 'masculino', 'Amazonia', 0]
# ['Amazonia-femenino', '4.6', 478, '2', 'casada', 'Secundaria', '27', 'femenino', 'Amazonia', 0]
# ['Amazonia-femenino', '2.9', 220, '4', 'divorciada', 'Secundaria', '43', 'femenino', 'Amazonia', 0]
# ['Amazonia-femenino', '1.9', 97, '4', 'casada', 'Profesional', '31', 'femenino', 'Amazonia', 0]
# ['Amazonia-femenino', '1.2', 280, '2', 'soltera', 'Secundaria', '36', 'femenino', 'Amazonia', 0]
# ['Amazonia-femenino', '0.2', 417, '2', 'casada', 'Secundaria', '18', 'femenino', 'Amazonia', 0]
# ******************Lista solo becados***************
# Region_Genero, Promedio,Index,Estrato,Estado Civil,Escolaridad,Edad,Genero, Numero de becas
# ['Pacifica-no binario', '4.0', 361, '1', 'divorciada', 'Profesional', '73', 'no binario', 'Pacifica', 1]
# ['Pacifica-masculino', '5.0', 376, '1', 'soltera', 'Secundaria', '69', 'masculino', 'Pacifica', 1]
# ['Pacifica-masculino', '4.9', 471, '3', 'soltera', 'Secundaria', '21', 'masculino', 'Pacifica', 1]
# ['Pacifica-masculino', '4.7', 385, '1', 'soltera', 'Secundaria', '49', 'masculino', 'Pacifica', 1]
# ['Pacifica-masculino', '4.4', 161, '3', 'casada', 'Secundaria', '26', 'masculino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.9', 363, '1', 'casada', 'Secundaria', '32', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.7', 109, '3', 'soltera', 'Profesional', '60', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.4', 355, '2', 'soltera', 'Maestria', '68', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.3', 287, '1', 'soltera', 'Secundaria', '20', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.2', 262, '2', 'casada', 'Secundaria', '36', 'femenino', 'Pacifica', 1]
# ['Pacifica-femenino', '4.0', 250, '1', 'divorciada', 'Secundaria', '25', 'femenino', 'Pacifica', 1]
# ['Orinoquia-masculino', '4.2', 422, '1', 'soltera', 'Secundaria', '50', 'masculino', 'Orinoquia', 1]
# ['Orinoquia-femenino', '3.9', 113, '2', 'divorciada', 'Profesional', '57', 'femenino', 'Orinoquia', 1]
# ['Caribe-no binario', '4.3', 22, '2', 'casada', 'Secundaria', '51', 'no binario', 'Caribe', 1]
# ['Caribe-masculino', '4.9', 491, '2', 'casada', 'Profesional', '59', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '4.6', 159, '3', 'soltera', 'Profesional', '55', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '4.1', 454, '3', 'casada', 'Secundaria', '50', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '4.0', 319, '3', 'soltera', 'Profesional', '74', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '4.0', 434, '1', 'soltera', 'Secundaria', '53', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '3.8', 169, '2', 'divorciada', 'Secundaria', '69', 'masculino', 'Caribe', 1]
# ['Caribe-masculino', '3.7', 202, '3', 'divorciada', 'Secundaria', '61', 'masculino', 'Caribe', 1]
# ['Caribe-femenino', '5.0', 243, '2', 'divorciada', 'Secundaria', '59', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.9', 60, '3', 'casada', 'Primaria', '75', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.4', 308, '2', 'divorciada', 'Secundaria', '30', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.3', 70, '2', 'casada', 'Secundaria', '79', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.2', 256, '3', 'casada', 'Secundaria', '56', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.2', 453, '3', 'casada', 'Profesional', '36', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.1', 108, '1', 'viuda', 'Profesional', '62', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.1', 213, '1', 'divorciada', 'Secundaria', '30', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.0', 145, '3', 'casada', 'Secundaria', '38', 'femenino', 'Caribe', 1]
# ['Caribe-femenino', '4.0', 433, '3', 'casada', 'Secundaria', '63', 'femenino', 'Caribe', 1]
# ['Andina-no binario', '4.8', 259, '5', 'soltera', 'Secundaria', '60', 'no binario', 'Andina', 1]
# ['Andina-masculino', '4.9', 162, '1', 'casada', 'Secundaria', '47', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.8', 394, '4', 'divorciada', 'Profesional', '69', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.5', 9, '3', 'soltera', 'Profesional', '80', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.5', 452, '2', 'casada', 'Secundaria', '53', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.4', 222, '2', 'soltera', 'Profesional', '34', 'masculino', 'Andina', 1]
# ['Andina-masculino', '4.3', 398, '1', 'casada', 'Secundaria', '52', 'masculino', 'Andina', 1]
# ['Andina-femenino', '4.9', 7, '2', 'casada', 'Secundaria', '54', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.9', 207, '2', 'casada', 'Profesional', '21', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.8', 137, '2', 'divorciada', 'Profesional', '70', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.5', 409, '2', 'divorciada', 'Secundaria', '58', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.2', 134, '3', 'soltera', 'Secundaria', '22', 'femenino', 'Andina', 1]
# ['Andina-femenino', '4.1', 45, '3', 'casada', 'Secundaria', '54', 'femenino', 'Andina', 1]

# %% [markdown]
# **Misión 6**
#
# Desarrollar un algoritmo, a partir de lo anterior, cuyo resultado permita al comité comparar fácilmente las características de las dos poblaciones hipotéticas que recibirían becas.
#
# *Ayuda*: considera utilizar tus implementaciones de la *Misión 2* para facilitar esta misión.

# %%
#Filtros Criterio de Seleccion grupo 1

#filtrar y agrupar por genero
filtro_g=[x[7] for x in becados_consolidado] 
filtro_g_g=[[x, filtro_g.count(x)] for x in set(filtro_g)]
print(filtro_g_g)

#filtrar y agrupar por educacion
filtro_e=[x[5] for x in becados_consolidado] 
filtro_e_e=[[x, filtro_e.count(x)] for x in set(filtro_e)]
print(filtro_e_e)

#filtrar y agrupar por estado civil
filtro_c=[x[4] for x in becados_consolidado] 
filtro_c_c=[[x, filtro_c.count(x)] for x in set(filtro_c)]
print(filtro_c_c)

#filtrar y agrupar por region
filtro_r=[x[3] for x in becados_consolidado] 
filtro_r_r=[[x, filtro_r.count(x)] for x in set(filtro_r)]
print(filtro_r_r)

#Filtros Criterio de Seleccion grupo 2****************************

#filtrar y agrupar por genero
filtro_g2=[x[7] for x in Lista_Becados] 
filtro_g_g2=[[x, filtro_g2.count(x)] for x in set(filtro_g2)]
print(filtro_g_g2)

#filtrar y agrupar por educacion
filtro_e2=[x[5] for x in Lista_Becados] 
filtro_e_e2=[[x, filtro_e2.count(x)] for x in set(filtro_e2)]
print(filtro_e_e2)

#filtrar y agrupar por estado civil
filtro_c2=[x[4] for x in Lista_Becados] 
filtro_c_c2=[[x, filtro_c2.count(x)] for x in set(filtro_c2)]
print(filtro_c_c2)

#filtrar y agrupar por region
filtro_r2=[x[8] for x in Lista_Becados] 
filtro_r_r2=[[x, filtro_r2.count(x)] for x in set(filtro_r2)]
print(filtro_r_r2)
# Out:
# [['masculino', 20], ['femenino', 28], ['no binario', 3]]
# [['Maestria', 1], ['Profesional', 14], ['Primaria', 1], ['Secundaria', 35]]
# [['casada', 23], ['viuda', 1], ['divorciada', 13], ['soltera', 14]]
# [['Pacifica', 14], ['Caribe', 16], ['Orinoquia', 3], ['Andina', 16], ['Amazonia', 2]]
# [['masculino', 18], ['femenino', 23], ['no binario', 3]]
# [['Maestria', 1], ['Profesional', 13], ['Primaria', 1], ['Secundaria', 29]]
# [['soltera', 14], ['casada', 18], ['viuda', 1], ['divorciada', 11]]
# [['Pacifica', 11], ['Andina', 13], ['Caribe', 18], ['Orinoquia', 2]]

# %%
# A continuacion graficos de barras con el numero de personas becadas segun diferentes variables
#Las graficas se hacen una al lado de la otra para una mejor comparacion visual


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(4, 2, sharey = False,figsize=(30,25))

ax[0,0].bar(x = [x[0] for x in filtro_g_g], height = [x[1] for x in filtro_g_g])
ax[0,0].set_title('No Becados segun Genero - Criterio Grupo 1', loc = 'center', fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[0,1].bar(x = [x[0] for x in filtro_g_g2], height = [x[1] for x in filtro_g_g2])
ax[0,1].set_title('No Becados segun Genero - Criterio Grupo 2', loc = 'center', fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[1,0].bar(x = [x[0] for x in filtro_e_e], height = [x[1] for x in filtro_e_e])
ax[1,0].set_title('No Becados segun Escolaridad - Criterio Grupo 1', loc = 'center', fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[1,1].bar(x = [x[0] for x in filtro_e_e2], height = [x[1] for x in filtro_e_e2])
ax[1,1].set_title('No Becados segun Escolaridad - Criterio Grupo 2', loc = 'center', fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[2,0].bar(x = [x[0] for x in filtro_c_c], height = [x[1] for x in filtro_c_c])
ax[2,0].set_title('No Becados segun Estado Civil - Criterio Grupo 1', loc = 'center', fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[2,1].bar(x = [x[0] for x in filtro_c_c2], height = [x[1] for x in filtro_c_c2])
ax[2,1].set_title('No Becados segun Estado Civil - Criterio Grupo 2', loc = 'center', fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[3,0].bar(x = [x[0] for x in filtro_r_r], height = [x[1] for x in filtro_r_r])
ax[3,0].set_title('No Becados segun Region - Criterio Grupo 2', loc = 'center', fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax[3,1].bar(x = [x[0] for x in filtro_r_r2], height = [x[1] for x in filtro_r_r2])
ax[3,1].set_title('No Becados segun Region - Criterio Grupo 2', loc = 'center', fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
plt.show()

# %% [markdown]
# ## 3. Desarrollo de una solución analítica
#
# Reconociendo la complejidad de este problema (que no permite reducirlo a una dicotomía) y viendo el potencial del análisis de datos para enriquecer la discusión y los insumos para tomar decisiones, el comité ha solicitado una herramienta analítica que les permita . Sus requerimientos son:
#
# * La herramienta debe permitir ingresar una política de selección de becados.
#     * Se debe poder elegir el rango de edad de los aspirantes.
#     * Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato, o a cada región (pero sólo debe elegirse uno de estos criterios).
# * La herramienta debe generar un resultado que permita al comité analizar las características de la población potencialmente elegida si se usara la política ingresada.
#
# **Misión 7**
#
# Desarrollar, a partir de lo construido hasta el momento, un algoritmo que permita cumplir con los requerimientos del comité.

# %%
# código

# Variables a ser modificadas por el usuario:

Becas = 50
Proporcion = 0.2
Edad_Minima = 16
Edad_Maxima = 40
criterio="region" #"estrato" o "genero" o "region"

#************************Herramienta- (No Modificar)*********************************************

#Criterio = Criterio_Region

#Base de Datos consolidad informacion de todas las listas

Datos_consolidados=[]

for i in range(len(datos_estrato)):
    lista_Consolidada=[]   
    lista_Consolidada.append(datos_estrato[i])
    lista_Consolidada.append(datos_promedio[i])    
    lista_Consolidada.append(i)
    lista_Consolidada.append(datos_region[i])
    lista_Consolidada.append(datos_estado_civil[i])
    lista_Consolidada.append(datos_escolaridad[i])
    lista_Consolidada.append(int_data_edades[i])
    lista_Consolidada.append(datos_genero[i])
    Datos_consolidados.append(lista_Consolidada)

#Criterio Rango de edad    
    
Datos_consolidados_rango_edad =[i for i in Datos_consolidados if Edad_Minima <= i[6] <= Edad_Maxima]

# Criterio_1 = Region

Criterio_Region =[[x] for x in set(datos_region)]
d_region={}
for j in range(len(Criterio_Region)):
    d_region[Criterio_Region[j][0]]=Proporcion*Becas


# Criterio_2 = Estrato

Criterio_Estrato =[[x] for x in set(datos_estrato)]
d_Estrato={}
for j in range(len(Criterio_Estrato)):
    d_Estrato[Criterio_Estrato[j][0]]=Proporcion*Becas

# Criterio_3 = Genero

Criterio_Genero =[[x] for x in set(datos_genero)]
d_Genero={}
for j in range(len(Criterio_Genero)):
    d_Genero[Criterio_Genero[j][0]]=Proporcion*Becas

Datos_consolidados_rango_edad

# Asignacion de becas criterio region*************************

if criterio == "region":
    print("Total de Becas segun Region:")
    print(d_region)
    Datos_Cons_Ordenados = sorted(Datos_consolidados_rango_edad, key=lambda x: (x[3],x[1]),reverse=True)
    
    # Asigna las becas por region en orden descendente segun el promedio

    for i in range(len(Datos_Cons_Ordenados)):
        estudiante_region = Datos_Cons_Ordenados[i]
        becas_asignadas_region=d_region[estudiante_region[3]]
        if(becas_asignadas_region>0):            
            estudiante_region.append(1)
            d_region[estudiante_region[3]]-=1
        else:
            estudiante_region.append(0)



    #Filtrar lista para traer solo a los estudiantes becados

    Lista_Becados_region = [i for i in Datos_Cons_Ordenados if i[8] == 1]
    print("Lista de Becados segun Region:")
    print(Lista_Becados_region)


# Asignacion de becas criterio estrato*************************

if criterio == "estrato":
    print("Total de Becas segun Estrato:")
    print(d_Estrato)
    Datos_Cons_Ordenados = sorted(Datos_consolidados_rango_edad, key=lambda x: (x[0],x[1]),reverse=True)
    
    # Asigna las becas por region en orden descendente segun el promedio

    for i in range(len(Datos_Cons_Ordenados)):
        estudiante_estrato = Datos_Cons_Ordenados[i]
        becas_asignadas_estrato=d_Estrato[estudiante_estrato[0]]
        if(becas_asignadas_estrato>0):            
            estudiante_estrato.append(1)
            d_Estrato[estudiante_estrato[0]]-=1
        else:
            estudiante_estrato.append(0)

    #Filtrar lista para traer solo a los estudiantes becados

    Lista_Becados_Estrato = [i for i in Datos_Cons_Ordenados if i[8] == 1]
    
    print("Lista de Becados segun Estrato:")
    print(Lista_Becados_Estrato)

# Asignacion de becas criterio genero *************************

if criterio == "genero":
    print("Total de Becas segun Genero:")
    print(d_Genero)
    Datos_Cons_Ordenados = sorted(Datos_consolidados_rango_edad, key=lambda x: (x[7],x[1]),reverse=True)
    
    # Asigna las becas por region en orden descendente segun el promedio

    for i in range(len(Datos_Cons_Ordenados)):
        estudiante_genero = Datos_Cons_Ordenados[i]
        becas_asignadas_genero=d_Genero[estudiante_genero[0]]
        if(becas_asignadas_genero>0):            
            estudiante_genero.append(1)
            d_Genero[estudiante_genero[0]]-=1
        else:
            estudiante_genero.append(0)



    #Filtrar lista para traer solo a los estudiantes becados

    Lista_Becados_Genero = [i for i in Datos_Cons_Ordenados if i[8] == 1]
    print("Lista de Becados segun Genero:")
    print(Lista_Becados_Genero)
# Out:
# Total de Becas segun Region:
# {'Pacifica': 10.0, 'Caribe': 10.0, 'Orinoquia': 10.0, 'Andina': 10.0, 'Amazonia': 10.0}
# Lista de Becados segun Region:
# [['1', '4.9', 363, 'Pacifica', 'casada', 'Secundaria', 32, 'femenino', 1], ['3', '4.9', 471, 'Pacifica', 'soltera', 'Secundaria', 21, 'masculino', 1], ['3', '4.4', 161, 'Pacifica', 'casada', 'Secundaria', 26, 'masculino', 1], ['1', '4.3', 287, 'Pacifica', 'soltera', 'Secundaria', 20, 'femenino', 1], ['2', '4.2', 262, 'Pacifica', 'casada', 'Secundaria', 36, 'femenino', 1], ['1', '4.0', 250, 'Pacifica', 'divorciada', 'Secundaria', 25, 'femenino', 1], ['2', '4.0', 337, 'Pacifica', 'divorciada', 'Profesional', 23, 'femenino', 1], ['3', '3.9', 188, 'Pacifica', 'casada', 'Primaria', 36, 'masculino', 1], ['2', '3.8', 240, 'Pacifica', 'casada', 'Secundaria', 24, 'masculino', 1], ['3', '3.7', 294, 'Pacifica', 'divorciada', 'Primaria', 39, 'femenino', 1], ['3', '3.0', 228, 'Orinoquia', 'casada', 'Secundaria', 32, 'femenino', 1], ['4', '2.9', 153, 'Orinoquia', 'casada', 'Secundaria', 20, 'femenino', 1], ['2', '2.8', 189, 'Orinoquia', 'soltera', 'Secundaria', 27, 'femenino', 1], ['1', '2.6', 58, 'Orinoquia', 'divorciada', 'Secundaria', 19, 'masculino', 1], ['2', '2.5', 261, 'Orinoquia', 'divorciada', 'Secundaria', 30, 'femenino', 1], ['4', '2.3', 320, 'Orinoquia', 'casada', 'Secundaria', 18, 'masculino', 1], ['2', '2.1', 4, 'Orinoquia', 'divorciada', 'Secundaria', 26, 'otro', 1], ['1', '2.1', 39, 'Orinoquia', 'soltera', 'Maestria', 30, 'masculino', 1], ['2', '2.1', 73, 'Orinoquia', 'casada', 'Secundaria', 18, 'femenino', 1], ['3', '2.1', 205, 'Orinoquia', 'divorciada', 'Profesional', 27, 'masculino', 1], ['2', '4.4', 308, 'Caribe', 'divorciada', 'Secundaria', 30, 'femenino', 1], ['3', '4.2', 453, 'Caribe', 'casada', 'Profesional', 36, 'femenino', 1], ['1', '4.1', 213, 'Caribe', 'divorciada', 'Secundaria', 30, 'femenino', 1], ['3', '4.0', 145, 'Caribe', 'casada', 'Secundaria', 38, 'femenino', 1], ['2', '3.8', 51, 'Caribe', 'casada', 'Profesional', 40, 'femenino', 1], ['3', '3.7', 291, 'Caribe', 'casada', 'Profesional', 18, 'masculino', 1], ['1', '3.7', 466, 'Caribe', 'soltera', 'Secundaria', 24, 'femenino', 1], ['2', '3.6', 341, 'Caribe', 'casada', 'Secundaria', 27, 'masculino', 1], ['3', '3.6', 442, 'Caribe', 'casada', 'Maestria', 25, 'femenino', 1], ['2', '3.5', 12, 'Caribe', 'casada', 'Secundaria', 40, 'femenino', 1], ['2', '4.9', 207, 'Andina', 'casada', 'Profesional', 21, 'femenino', 1], ['1', '4.8', 283, 'Andina', 'divorciada', 'Secundaria', 28, 'no binario', 1], ['2', '4.4', 222, 'Andina', 'soltera', 'Profesional', 34, 'masculino', 1], ['3', '4.2', 134, 'Andina', 'soltera', 'Secundaria', 22, 'femenino', 1], ['3', '4.0', 74, 'Andina', 'casada', 'Profesional', 22, 'femenino', 1], ['2', '3.9', 33, 'Andina', 'casada', 'Secundaria', 26, 'masculino', 1], ['1', '3.7', 163, 'Andina', 'viuda', 'Profesional', 20, 'masculino', 1], ['3', '3.6', 311, 'Andina', 'soltera', 'Profesional', 29, 'masculino', 1], ['2', '3.6', 338, 'Andina', 'soltera', 'Secundaria', 26, 'masculino', 1], ['2', '3.5', 146, 'Andina', 'divorciada', 'Profesional', 19, 'femenino', 1], ['2', '4.6', 478, 'Amazonia', 'casada', 'Secundaria', 27, 'femenino', 1], ['3', '4.5', 49, 'Amazonia', 'soltera', 'Secundaria', 20, 'masculino', 1], ['3', '3.3', 488, 'Amazonia', 'soltera', 'Secundaria', 39, 'masculino', 1], ['4', '1.9', 97, 'Amazonia', 'casada', 'Profesional', 31, 'femenino', 1], ['3', '1.5', 375, 'Amazonia', 'casada', 'Secundaria', 21, 'no binario', 1], ['1', '1.2', 83, 'Amazonia', 'divorciada', 'Maestria', 38, 'masculino', 1], ['2', '1.2', 280, 'Amazonia', 'soltera', 'Secundaria', 36, 'femenino', 1], ['4', '0.9', 301, 'Amazonia', 'casada', 'Secundaria', 30, 'masculino', 1], ['2', '0.2', 417, 'Amazonia', 'casada', 'Secundaria', 18, 'femenino', 1]]

# %% [markdown]
# **Misión 8**
#
# Proponer, con base en tu propio uso de la herramienta, una política de ingreso que consideres apropiada dado el contexto proporcionado. Si lo crees adecuado, explica, máximo 500 caracteres, las virtudes de tu propuesta (esto puede estar soportado en los datos, o no).

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

respuesta = 'Asignaria un porcentaje sobre cada "region", escogiendo los mejores puntajes en un rango de edad de 16 a 40 años, asi considero equitativa la participacion de estudiante a nivel nacional sin discriminarlos por genero o estrato social, en mi opinion seria mas trasparente'

# %% [markdown]
# **Misión 9**
#
# Ejecutar el algoritmo desarrollado en la *Misión 7* sobre la política que sugieres proponer al comité. Explicar claramente tus conlusiones con el soporte de los resultados de la herramienta.

# %%
# código

conclusion = 'Al seleccionar Region como criterio y equitativamente distribuir el 20% de las becas en cada region, tenemos que se asignaron el 100% de las becas disponibles, siendo el promedio la  base de asignacion. De esta forma confirmo que se premia a los estudiantes que se esforzaron por tener un mejor desempeño sin tener en cuenta su genero, estrato social o cualquier otra variable que pudiera afectar la desicion'

# Total de Becas segun Region:
# {'Pacifica': 10.0, 'Caribe': 10.0, 'Orinoquia': 10.0, 'Andina': 10.0, 'Amazonia': 10.0}

filtro_genero  = [x[7] for x in Lista_Becados_region] 
filtro_genero_g =[[x, filtro_genero.count(x)] for x in set(filtro_genero)]

filtro_Estrato  = [x[0] for x in Lista_Becados_region] 
filtro_Estrato_g =[[x, filtro_Estrato.count(x)] for x in set(filtro_Estrato)]

print("Personas Becadas segun Genero :" + str(filtro_genero_g)) 
print("Personas Becadas segun su Estrato :" + str(filtro_Estrato_g))
# Out:
# Personas Becadas segun Genero :[['masculino', 19], ['femenino', 27], ['otro', 1], ['no binario', 2]]
# Personas Becadas segun su Estrato :[['2', 19], ['1', 10], ['4', 4], ['3', 16]]

# %% [markdown]
# ## Referencias
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# Camilo Gómez - 11/06/21<br>
# *Revisado*: 25/08/21
